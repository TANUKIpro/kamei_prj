# %%
# %matplotlib inline
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

#シミュレーション結果が入っているフォルダのアドレス
file_address = '/Users/ryotaro/Desktop/kamei/kaiseki7/'

#シミュレーションした時の抑制の有無
#抑制なし→\without_inhibitory
#抑制あり→\with_inhibitory
simulation_state = 'control'


file_name = file_address + 'DD.csv'
DD= np.loadtxt(file_name, delimiter=',')

#行数の読み込み
row = len(DD)

ave = np.zeros(row)


ave_bias = np.abs(np.mean(ave))

DD = DD + ave_bias
fig_DD = plt.figure()

plt.xlim([8000,30000])
plt.ylim([-0.6,2.5])

plt.plot(DD)
#save_name = file_address + '\\' + simulation_state + '_DD.jpg'
#fig_DD.savefig(save_name)

file_name = file_address + 'MD.csv'
MD= np.loadtxt(file_name, delimiter=',')+ave_bias
fig_MD = plt.figure()

plt.xlim([8000,30000])
plt.ylim([-0.6,2.5])

plt.plot(MD)
#save_name = file_address + '\\' + simulation_state + '_MD.jpg'
#fig_MD.savefig(save_name)


#理論波形作成用
ArtificalData = np.zeros(row)

#ピーク値格納用
afPeakResult = np.zeros(9)
rdPeakResult = np.zeros(9)
summennseki1=np.zeros(9) #面積比格納(理論値)
summennseki2=np.zeros(9) #面積比格納(実測値)

#ピーク値の比の格納用
PeakResult = np.zeros(9)


#0ms
ArtificalData = DD+MD

file_name = file_address + simulation_state + '_0ms.csv'
RowData = np.loadtxt(file_name, delimiter=',')+ave_bias

fig_0ms = plt.figure()

plt.xlim([8000,30000])
plt.ylim([-0.6,2.5])

plt.plot(ArtificalData)
plt.plot(RowData)
#save_name = file_address + '\\' + simulation_state + '_0ms.jpg'
#fig_0ms.savefig(save_name)

afPeakResult[4] = ArtificalData.max()
rdPeakResult[4] = RowData.max()
summennseki1[4] = ArtificalData.sum()
summennseki2[4] = RowData.sum()

#+5ms
i = 0
j = 0
dt = 1000   #⊿t
for num1 in range(dt):
    ArtificalData[i] = MD[i]
    i = i+1
for num2 in range(row-dt):
    ArtificalData[i] = MD[i] + DD[j]
    i = i+1
    j = j+1

file_name = file_address + simulation_state + '_5ms.csv'
RowData = np.loadtxt(file_name, delimiter=',')+ave_bias

fig_5ms = plt.figure()

plt.xlim([8000,30000])
plt.ylim([-0.6,2.5])

plt.plot(ArtificalData)
plt.plot(RowData)
#save_name = file_address + '\\' + simulation_state + '_5ms.jpg'
#fig_5ms.savefig(save_name)

afPeakResult[5] = ArtificalData.max()
rdPeakResult[5] = RowData.max()
summennseki1[5] = ArtificalData.sum()
summennseki2[5] = RowData.sum()

#-5ms
i = 0
j = 0
dt = 1000   #⊿t
for num1 in range(dt):
    ArtificalData[i] = DD[i]
    i = i+1
for num2 in range(row-dt):
    ArtificalData[i] = DD[i] + MD[j]
    i = i+1
    j = j+1
    
file_name = file_address + simulation_state + '_-5ms.csv'
RowData = np.loadtxt(file_name, delimiter=',')+ave_bias

fig_m5ms = plt.figure()

plt.xlim([8000,30000])
plt.ylim([-0.6,2.5])

plt.plot(ArtificalData)
plt.plot(RowData)
#save_name = file_address + '\\' + simulation_state + '_-5ms.jpg'
#fig_m5ms.savefig(save_name)

afPeakResult[3] = ArtificalData.max()
rdPeakResult[3] = RowData.max()
summennseki1[3] = ArtificalData.sum()
summennseki2[3] = RowData.sum()

#+10ms
i = 0
j = 0
dt = 2000   #⊿t
for num1 in range(dt):
    ArtificalData[i] = MD[i]
    i = i+1
for num2 in range(row-dt):
    ArtificalData[i] = MD[i] + DD[j]
    i = i+1
    j = j+1

file_name = file_address + simulation_state + '_10ms.csv'
RowData = np.loadtxt(file_name, delimiter=',')+ave_bias

fig_10ms = plt.figure()

plt.xlim([8000,30000])
plt.ylim([-0.6,2.5])

plt.plot(ArtificalData)
plt.plot(RowData)
#save_name = file_address + '\\' + simulation_state + '_10ms.jpg'
#fig_10ms.savefig(save_name)

afPeakResult[6] = ArtificalData.max()
rdPeakResult[6] = RowData.max()
summennseki1[6] = ArtificalData.sum()
summennseki2[6] = RowData.sum()

#-10ms
i = 0
j = 0
dt = 2000   #⊿t
for num1 in range(dt):
    ArtificalData[i] = DD[i]
    i = i+1
for num2 in range(row-dt):
    ArtificalData[i] = DD[i] + MD[j]
    i = i+1
    j = j+1

file_name = file_address + simulation_state + '_-10ms.csv'
RowData = np.loadtxt(file_name, delimiter=',')+ave_bias

fig_m10ms = plt.figure()

plt.xlim([8000,30000])
plt.ylim([-0.6,2.5])

plt.plot(ArtificalData)
plt.plot(RowData)
#save_name = file_address + '\\' + simulation_state + '_-10ms.jpg'
#fig_m10ms.savefig(save_name)

afPeakResult[2] = ArtificalData.max()
rdPeakResult[2] = RowData.max()
summennseki1[2] = ArtificalData.sum()
summennseki2[2] = RowData.sum()

#+20ms
i = 0
j = 0
dt = 4000   #⊿t
for num1 in range(dt):
    ArtificalData[i] = MD[i]
    i = i+1
for num2 in range(row-dt):
    ArtificalData[i] = MD[i] + DD[j]
    i = i+1
    j = j+1

file_name = file_address + simulation_state + '_20ms.csv'
RowData = np.loadtxt(file_name, delimiter=',')+ave_bias

fig_20ms = plt.figure()

plt.xlim([8000,30000])
plt.ylim([-0.6,2.5])

plt.plot(ArtificalData)
plt.plot(RowData)
#save_name = file_address + '\\' + simulation_state + '_20ms.jpg'
#fig_20ms.savefig(save_name)

afPeakResult[7] = ArtificalData.max()
rdPeakResult[7] = RowData.max()
summennseki1[7] = ArtificalData.sum()
summennseki2[7] = RowData.sum()

#-20ms
i = 0
j = 0
dt = 4000   #⊿t
for num1 in range(dt):
    ArtificalData[i] = DD[i]
    i = i+1
for num2 in range(row-dt):
    ArtificalData[i] = DD[i] + MD[j]
    i = i+1
    j = j+1
    
file_name = file_address + simulation_state + '_-20ms.csv'
RowData = np.loadtxt(file_name, delimiter=',')+ave_bias

fig_m20ms = plt.figure()

plt.xlim([8000,30000])
plt.ylim([-0.6,2.5])

plt.plot(ArtificalData)
plt.plot(RowData)
#save_name = file_address + '\\' + simulation_state + '_-20ms.jpg'
#fig_m20ms.savefig(save_name)

afPeakResult[1] = ArtificalData.max()
rdPeakResult[1] = RowData.max()
summennseki1[1] = ArtificalData.sum()
summennseki2[1] = RowData.sum()

#+40ms
i = 0
j = 0
dt = 8000   #⊿t
for num1 in range(dt):
    ArtificalData[i] = MD[i]
    i = i+1
for num2 in range(row-dt):
    ArtificalData[i] = MD[i] + DD[j]
    i = i+1
    j = j+1

file_name = file_address + simulation_state + '_40ms.csv'
RowData = np.loadtxt(file_name, delimiter=',')+ave_bias

fig_40ms = plt.figure()

plt.xlim([8000,30000])
plt.ylim([-0.6,2.5])

plt.plot(ArtificalData)
plt.plot(RowData)
#save_name = file_address + '\\' + simulation_state + '_40ms.jpg'
#fig_40ms.savefig(save_name)

afPeakResult[8] = ArtificalData.max()
rdPeakResult[8] = RowData.max()
summennseki1[8] = ArtificalData.sum()
summennseki2[8] = RowData.sum()

#-40ms
i = 0
j = 0
dt = 8000   #⊿t
for num1 in range(dt):
    ArtificalData[i] = DD[i]
    i = i+1
for num2 in range(row-dt):
    ArtificalData[i] = DD[i] + MD[j]
    i = i+1
    j = j+1

file_name = file_address + simulation_state + '_-40ms.csv'
RowData = np.loadtxt(file_name, delimiter=',')+ave_bias

fig_m40ms = plt.figure()

plt.xlim([8000,30000])
plt.ylim([-0.6,2.5])

plt.plot(ArtificalData)
plt.plot(RowData)
#save_name = file_address + '\\' + simulation_state + '_-40ms.jpg'
#fig_m40ms.savefig(save_name)

afPeakResult[0] = ArtificalData.max()
rdPeakResult[0] = RowData.max()
summennseki1[0] = ArtificalData.sum()
summennseki2[0] = RowData.sum()

PeakResult = rdPeakResult/afPeakResult
SumResult = summennseki2/summennseki1

print(rdPeakResult)
print(afPeakResult)
print(PeakResult) #ピーク値Excel　Go
print(SumResult)#面積値Excel　Go
# Out:
# [0.08755287 0.08720945 0.07626593 0.08607747 0.07044692 0.09532088
#  0.09554424 0.11130721 0.08108504]
# [0.07696128 0.07792971 0.07741792 0.07831568 0.12084712 0.0980114
#  0.09507237 0.07290479 0.07249505]
# [1.13762222 1.11907824 0.98511983 1.09910898 0.58294252 0.97254893
#  1.00496324 1.52674757 1.11849065]
# [0.48138254 0.53620762 0.78162476 0.14263104 1.07182729 0.83097912
#  1.38973352 0.81009178 1.52923535]

# %%
# %matplotlib inline
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

#シミュレーション結果が入っているフォルダのアドレス
file_address = 'C:\kaiseki7'

#シミュレーションした時の抑制の有無
#抑制なし→\without_inhibitory
#抑制あり→\with_inhibitory
simulation_state = 'withoutIn'


file_name = file_address + '\\' + simulation_state + '_DD.csv'
DD= np.loadtxt(file_name, delimiter=',')

#行数の読み込み
row = len(DD)

ave = np.zeros(row)


ave_bias = np.abs(np.mean(ave))

DD = DD + ave_bias
fig_DD = plt.figure()

plt.xlim([8000,30000])
plt.ylim([-0.3,0.5])

plt.plot(DD)
save_name = file_address + '\\' + simulation_state + '_DD.jpg'
fig_DD.savefig(save_name)

file_name = file_address + '\\' + simulation_state + '_MD.csv'
MD= np.loadtxt(file_name, delimiter=',')+ave_bias
fig_MD = plt.figure()

plt.xlim([8000,30000])
plt.ylim([-0.6,2.5])

plt.plot(MD)
save_name = file_address + '\\' + simulation_state + '_MD.jpg'
fig_MD.savefig(save_name)


#理論波形作成用
ArtificalData = np.zeros(row)

#ピーク値格納用
afPeakResult = np.zeros(9)
rdPeakResult = np.zeros(9)
summennseki1=np.zeros(9) #面積比格納(理論値)
summennseki2=np.zeros(9) #面積比格納(実測値)

#ピーク値の比の格納用
PeakResult = np.zeros(9)


#0ms
ArtificalData = DD+MD

file_name = file_address + '\\' + simulation_state + '_0ms.csv'
RowData = np.loadtxt(file_name, delimiter=',')+ave_bias

fig_0ms = plt.figure()

plt.xlim([8000,30000])
plt.ylim([-0.6,2.5])

plt.plot(ArtificalData)
plt.plot(RowData)
save_name = file_address + '\\' + simulation_state + '_0ms.jpg'
fig_0ms.savefig(save_name)

afPeakResult[4] = ArtificalData.max()
rdPeakResult[4] = RowData.max()
summennseki1[4] = ArtificalData.sum()
summennseki2[4] = RowData.sum()

#+5ms
i = 0
j = 0
dt = 1000   #⊿t
for num1 in range(dt):
    ArtificalData[i] = MD[i]
    i = i+1
for num2 in range(row-dt):
    ArtificalData[i] = MD[i] + DD[j]
    i = i+1
    j = j+1

file_name = file_address + '\\' + simulation_state + '_5ms.csv'
RowData = np.loadtxt(file_name, delimiter=',')+ave_bias

fig_5ms = plt.figure()

plt.xlim([8000,30000])
plt.ylim([-0.6,2.5])

plt.plot(ArtificalData)
plt.plot(RowData)
save_name = file_address + '\\' + simulation_state + '_5ms.jpg'
fig_5ms.savefig(save_name)

afPeakResult[5] = ArtificalData.max()
rdPeakResult[5] = RowData.max()
summennseki1[5] = ArtificalData.sum()
summennseki2[5] = RowData.sum()

#-5ms
i = 0
j = 0
dt = 1000   #⊿t
for num1 in range(dt):
    ArtificalData[i] = DD[i]
    i = i+1
for num2 in range(row-dt):
    ArtificalData[i] = DD[i] + MD[j]
    i = i+1
    j = j+1
    
file_name = file_address + '\\' + simulation_state + '_-5ms.csv'
RowData = np.loadtxt(file_name, delimiter=',')+ave_bias

fig_m5ms = plt.figure()

plt.xlim([8000,30000])
plt.ylim([-0.6,2.5])

plt.plot(ArtificalData)
plt.plot(RowData)
save_name = file_address + '\\' + simulation_state + '_-5ms.jpg'
fig_m5ms.savefig(save_name)

afPeakResult[3] = ArtificalData.max()
rdPeakResult[3] = RowData.max()
summennseki1[3] = ArtificalData.sum()
summennseki2[3] = RowData.sum()

#+10ms
i = 0
j = 0
dt = 2000   #⊿t
for num1 in range(dt):
    ArtificalData[i] = MD[i]
    i = i+1
for num2 in range(row-dt):
    ArtificalData[i] = MD[i] + DD[j]
    i = i+1
    j = j+1

file_name = file_address + '\\' + simulation_state + '_10ms.csv'
RowData = np.loadtxt(file_name, delimiter=',')+ave_bias

fig_10ms = plt.figure()

plt.xlim([8000,30000])
plt.ylim([-0.6,2.5])

plt.plot(ArtificalData)
plt.plot(RowData)
save_name = file_address + '\\' + simulation_state + '_10ms.jpg'
fig_10ms.savefig(save_name)

afPeakResult[6] = ArtificalData.max()
rdPeakResult[6] = RowData.max()
summennseki1[6] = ArtificalData.sum()
summennseki2[6] = RowData.sum()

#-10ms
i = 0
j = 0
dt = 2000   #⊿t
for num1 in range(dt):
    ArtificalData[i] = DD[i]
    i = i+1
for num2 in range(row-dt):
    ArtificalData[i] = DD[i] + MD[j]
    i = i+1
    j = j+1

file_name = file_address + '\\' + simulation_state + '_-10ms.csv'
RowData = np.loadtxt(file_name, delimiter=',')+ave_bias

fig_m10ms = plt.figure()

plt.xlim([8000,30000])
plt.ylim([-0.6,2.5])

plt.plot(ArtificalData)
plt.plot(RowData)
save_name = file_address + '\\' + simulation_state + '_-10ms.jpg'
fig_m10ms.savefig(save_name)

afPeakResult[2] = ArtificalData.max()
rdPeakResult[2] = RowData.max()
summennseki1[2] = ArtificalData.sum()
summennseki2[2] = RowData.sum()

#+20ms
i = 0
j = 0
dt = 4000   #⊿t
for num1 in range(dt):
    ArtificalData[i] = MD[i]
    i = i+1
for num2 in range(row-dt):
    ArtificalData[i] = MD[i] + DD[j]
    i = i+1
    j = j+1

file_name = file_address + '\\' + simulation_state + '_20ms.csv'
RowData = np.loadtxt(file_name, delimiter=',')+ave_bias

fig_20ms = plt.figure()

plt.xlim([8000,30000])
plt.ylim([-0.6,2.5])

plt.plot(ArtificalData)
plt.plot(RowData)
save_name = file_address + '\\' + simulation_state + '_20ms.jpg'
fig_20ms.savefig(save_name)

afPeakResult[7] = ArtificalData.max()
rdPeakResult[7] = RowData.max()
summennseki1[7] = ArtificalData.sum()
summennseki2[7] = RowData.sum()

#-20ms
i = 0
j = 0
dt = 4000   #⊿t
for num1 in range(dt):
    ArtificalData[i] = DD[i]
    i = i+1
for num2 in range(row-dt):
    ArtificalData[i] = DD[i] + MD[j]
    i = i+1
    j = j+1
    
file_name = file_address + '\\' + simulation_state + '_-20ms.csv'
RowData = np.loadtxt(file_name, delimiter=',')+ave_bias

fig_m20ms = plt.figure()

plt.xlim([8000,30000])
plt.ylim([-0.6,2.5])

plt.plot(ArtificalData)
plt.plot(RowData)
save_name = file_address + '\\' + simulation_state + '_-20ms.jpg'
fig_m20ms.savefig(save_name)

afPeakResult[1] = ArtificalData.max()
rdPeakResult[1] = RowData.max()

#+40ms
i = 0
j = 0
dt = 8000   #⊿t
for num1 in range(dt):
    ArtificalData[i] = MD[i]
    i = i+1
for num2 in range(row-dt):
    ArtificalData[i] = MD[i] + DD[j]
    i = i+1
    j = j+1

file_name = file_address + '\\' + simulation_state + '_40ms.csv'
RowData = np.loadtxt(file_name, delimiter=',')+ave_bias

fig_40ms = plt.figure()

plt.xlim([8000,30000])
plt.ylim([-0.6,2.5])

plt.plot(ArtificalData)
plt.plot(RowData)
save_name = file_address + '\\' + simulation_state + '_40ms.jpg'
fig_40ms.savefig(save_name)

afPeakResult[8] = ArtificalData.max()
rdPeakResult[8] = RowData.max()
summennseki1[8] = ArtificalData.sum()
summennseki2[8] = RowData.sum()

#-40ms
i = 0
j = 0
dt = 8000   #⊿t
for num1 in range(dt):
    ArtificalData[i] = DD[i]
    i = i+1
for num2 in range(row-dt):
    ArtificalData[i] = DD[i] + MD[j]
    i = i+1
    j = j+1

file_name = file_address + '\\' + simulation_state + '_-40ms.csv'
RowData = np.loadtxt(file_name, delimiter=',')+ave_bias

fig_m40ms = plt.figure()

plt.xlim([8000,30000])
plt.ylim([-0.6,2.5])

plt.plot(ArtificalData)
plt.plot(RowData)
save_name = file_address + '\\' + simulation_state + '_-40ms.jpg'
fig_m40ms.savefig(save_name)

afPeakResult[0] = ArtificalData.max()
rdPeakResult[0] = RowData.max()
summennseki1[0] = ArtificalData.sum()
summennseki2[0] = RowData.sum()

PeakResult = rdPeakResult/afPeakResult
SumResult = summennseki2/summennseki1

print(rdPeakResult)
print(afPeakResult)
print(PeakResult) #ピーク値Excel　Go
print(SumResult)#面積値Excel　Go
# Out:
# [0.06606139 0.08262266 0.06703021 0.09762185 0.09135588 0.11291044
#  0.12199555 0.07529625 0.08537678]
# [0.15956334 0.15312582 0.15223828 0.16093351 0.14049896 0.20095537
#  0.18921583 0.15389347 0.15798404]
# [0.41401359 0.53957363 0.44029797 0.6065974  0.65022461 0.56186824
#  0.64474282 0.48927511 0.54041394]
# [ 0.59168775         nan  1.05884173  0.46765847 -4.24522231  0.38016552
#   2.77712459  0.75838377  0.74953671]
# <ipython-input-4-2c156b3e16e5>:321: RuntimeWarning: invalid value encountered in true_divide
#   SumResult = summennseki2/summennseki1
